# %% [markdown]
# # Automação de Sistemas e Processos com Python
#
# ### Desafio:
#
# Todos os dias, o nosso sistema atualiza as vendas do dia anterior.
# O seu trabalho diário, como analista, é enviar um e-mail para a diretoria, assim que começar a trabalhar, com o faturamento e a quantidade de produtos vendidos no dia anterior
#
# E-mail da diretoria: seugmail+diretoria@gmail.com<br>
# Local onde o sistema disponibiliza as vendas do dia anterior: https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga?usp=sharing
#
# Para resolver isso, vamos usar o pyautogui, uma biblioteca de automação de comandos do mouse e do teclado

# %%
# Passo a passo do desafio:
# Passo 1: Entrar no sistema da empresa (link do drive)
# Passo 2: Navegar no sistema para encontrar a base de dados
# Passo 3: Exportar a base de dados (baixar arquivo)
# Passo 4: Calcular os indicadores (faturamento e quantidade de produtos vendidos)
# Passo 5: Enviar as informaçõe spor e-mail

# Instalação: 
# pyautogui -> automação
# pandas -> dados
# openpyxl -> trabalhar com bases de dados em excel.


# pyautogui.click -> clicar
# pyautogui.press -> apertar 1 tecla
# pyautogui.hotkey -> conjunto de teclas
# pyautogui.write -> escreve um texto

# %%
import pyautogui
import time

# Passo 1: Entrar no sistema da empresa (no nosso caso é o link do drive)
pyautogui.press("win")
pyautogui.write("chrome")
pyautogui.press("enter")

time.sleep(5)

#Link sistema: 
link = "https://drive.google.com/drive/folders/149xknr9JvrlEnhNWO49zPcw0PW5icxga"
pyautogui.write(link)

# apertei enter e esperei
pyautogui.press("enter")
time.sleep(5)

# %%
# Passo 2: Navegar no sistema e encontrar a base de vendas (entrar na pasta exportar)
pyautogui.click(x=167, y=360, clicks=2)
time.sleep(3)

# %%
# Passo 3: Fazer o download da base de vendas
pyautogui.click(x=1738, y=305) # clicar no fazer download
time.sleep(5) # esperar o download acabar
# Out:
# ---------------------------------------------------------------------------
# FailSafeException                         Traceback (most recent call last)
# Cell In[5], line 4
#       2 pyautogui.click(x=1100, y=904) # clicar no arquivo
#       3 pyautogui.click(x=3288, y=411) # clicar nos 3 pontinhos
# ----> 4 pyautogui.click(x=2716, y=1523) # clicar no fazer download
#       5 time.sleep(5) # esperar o download acabar
#
# File c:\Users\Vitor\AppData\Local\Programs\Python\Python312\Lib\site-packages\pyautogui\__init__.py:594, in _genericPyAutoGUIChecks.<locals>.wrapper(*args, **kwargs)
#     591 @functools.wraps(wrappedFunction)
#     592 def wrapper(*args, **kwargs):
#     593     failSafeCheck()
# --> 594     returnVal = wrappedFunction(*args, **kwargs)
#     595     _handlePause(kwargs.get("_pause", True))
#     596     return returnVal
#
# ...

# %% [markdown]
# ### Vamos agora ler o arquivo baixado para pegar os indicadores
#
# - Faturamento
# - Quantidade de Produtos

# %% [markdown]
# ### Vamos agora enviar um e-mail pelo gmail

# %% [markdown]
# #### Use esse código para descobrir qual a posição de um item que queira clicar
#
# - Lembre-se: a posição na sua tela é diferente da posição na minha tela

# %%
time.sleep(5)
print(pyautogui.position())
# Out:
# Point(x=1738, y=305)
